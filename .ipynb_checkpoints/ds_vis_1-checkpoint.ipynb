# %% [markdown]
# ### 1. NOTES ON OPERATION OF THE NOTEBOOKS
# We are analysisng the dataset using both seaborn and pandas frame.

# %% [markdown]
# #### 2a. import the required dependencies modules or packages

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### 2b. load the dataset

# %%
covid_df =pd.read_csv(r"C:\Users\User\Desktop\Data_Science_Projects\DataScience_VISULAISATION\datasets\covid_19_data_3.csv")

# %% [markdown]
# #### 3a. general view of the dataset

# %%
covid_df #displays some random rows and columns
# Out:
#          SNo ObservationDate     Province/State  Country/Region  \
# 0          1      01/22/2020              Anhui  Mainland China
# 1          2      01/22/2020            Beijing  Mainland China
# 2          3      01/22/2020          Chongqing  Mainland China
# 3          4      01/22/2020             Fujian  Mainland China
# 4          5      01/22/2020              Gansu  Mainland China
# ...      ...             ...                ...             ...
# 98247  98248      08/29/2020  Zaporizhia Oblast         Ukraine
# 98248  98249      08/29/2020            Zeeland     Netherlands
# 98249  98250      08/29/2020           Zhejiang  Mainland China
# 98250  98251      08/29/2020    Zhytomyr Oblast         Ukraine
# 98251  98252      08/29/2020       Zuid-Holland     Netherlands
#
#                Last Update  Confirmed  Deaths  Recovered
# 0          1/22/2020 17:00        1.0     0.0        0.0
# 1          1/22/2020 17:00       14.0     0.0        0.0
# 2          1/22/2020 17:00        6.0     0.0        0.0
# 3          1/22/2020 17:00        1.0     0.0        0.0
# 4          1/22/2020 17:00        0.0     0.0        0.0
# ...                    ...        ...     ...        ...
# 98247  2020-08-30 04:28:22     1520.0    25.0      883.0
# 98248  2020-08-30 04:28:22     1048.0    72.0        0.0
# 98249  2020-08-30 04:28:22     1277.0     1.0     1268.0
# 98250  2020-08-30 04:28:22     3155.0    61.0     1837.0
# 98251  2020-08-30 04:28:22    18774.0  1344.0        0.0
#
# [98252 rows x 8 columns]

# %%
covid_df.head() #displays the first five rows
# Out:
#    SNo ObservationDate Province/State  Country/Region      Last Update  \
# 0    1      01/22/2020          Anhui  Mainland China  1/22/2020 17:00
# 1    2      01/22/2020        Beijing  Mainland China  1/22/2020 17:00
# 2    3      01/22/2020      Chongqing  Mainland China  1/22/2020 17:00
# 3    4      01/22/2020         Fujian  Mainland China  1/22/2020 17:00
# 4    5      01/22/2020          Gansu  Mainland China  1/22/2020 17:00
#
#    Confirmed  Deaths  Recovered
# 0        1.0     0.0        0.0
# 1       14.0     0.0        0.0
# 2        6.0     0.0        0.0
# 3        1.0     0.0        0.0
# 4        0.0     0.0        0.0

# %%
covid_df.tail() #displays the last five rows of the datasets
# Out:
#          SNo ObservationDate     Province/State  Country/Region  \
# 98247  98248      08/29/2020  Zaporizhia Oblast         Ukraine
# 98248  98249      08/29/2020            Zeeland     Netherlands
# 98249  98250      08/29/2020           Zhejiang  Mainland China
# 98250  98251      08/29/2020    Zhytomyr Oblast         Ukraine
# 98251  98252      08/29/2020       Zuid-Holland     Netherlands
#
#                Last Update  Confirmed  Deaths  Recovered
# 98247  2020-08-30 04:28:22     1520.0    25.0      883.0
# 98248  2020-08-30 04:28:22     1048.0    72.0        0.0
# 98249  2020-08-30 04:28:22     1277.0     1.0     1268.0
# 98250  2020-08-30 04:28:22     3155.0    61.0     1837.0
# 98251  2020-08-30 04:28:22    18774.0  1344.0        0.0

# %%
covid_df.describe() #displays a quick stats summary
# Out:
#                 SNo      Confirmed        Deaths     Recovered
# count  98252.000000   98252.000000  98252.000000  9.825200e+04
# mean   49126.500000   15442.707232    692.502310  8.392821e+03
# std    28363.053661   46813.313272   2712.094164  4.751247e+04
# min        1.000000       0.000000      0.000000  0.000000e+00
# 25%    24563.750000     181.000000      2.000000  2.000000e+00
# 50%    49126.500000    1622.000000     31.000000  2.870000e+02
# 75%    73689.250000    8301.250000    264.000000  2.850000e+03
# max    98252.000000  801422.000000  42072.000000  2.140614e+06

# %%
covid_df.info # displays basic info of the dataset
# Out:
# <bound method DataFrame.info of          SNo ObservationDate     Province/State  Country/Region  \
# 0          1      01/22/2020              Anhui  Mainland China
# 1          2      01/22/2020            Beijing  Mainland China
# 2          3      01/22/2020          Chongqing  Mainland China
# 3          4      01/22/2020             Fujian  Mainland China
# 4          5      01/22/2020              Gansu  Mainland China
# ...      ...             ...                ...             ...
# 98247  98248      08/29/2020  Zaporizhia Oblast         Ukraine
# 98248  98249      08/29/2020            Zeeland     Netherlands
# 98249  98250      08/29/2020           Zhejiang  Mainland China
# 98250  98251      08/29/2020    Zhytomyr Oblast         Ukraine
# 98251  98252      08/29/2020       Zuid-Holland     Netherlands
#
#                Last Update  Confirmed  Deaths  Recovered
# 0          1/22/2020 17:00        1.0     0.0        0.0
# 1          1/22/2020 17:00       14.0     0.0        0.0
# 2          1/22/2020 17:00        6.0     0.0        0.0
# 3          1/22/2020 17:00        1.0     0.0        0.0
# 4          1/22/2020 17:00        0.0     0.0        0.0
# ...                    ...        ...     ...        ...
# 98247  2020-08-30 04:28:22     1520.0    25.0      883.0
# 98248  2020-08-30 04:28:22     1048.0    72.0        0.0
# 98249  2020-08-30 04:28:22     1277.0     1.0     1268.0
# 98250  2020-08-30 04:28:22     3155.0    61.0     1837.0
# 98251  2020-08-30 04:28:22    18774.0  1344.0        0.0
#
# [98252 rows x 8 columns]>

# %%
covid_df.columns #displays column names
# Out:
# Index(['SNo', 'ObservationDate', 'Province/State', 'Country/Region',
#        'Last Update', 'Confirmed', 'Deaths', 'Recovered'],
#       dtype='object')

# %%
covid_df.nunique() # displays the unique values in columns
# Out:
# SNo                98252
# ObservationDate      221
# Province/State       723
# Country/Region       223
# Last Update         1962
# Confirmed          27310
# Deaths              6527
# Recovered          17342
# dtype: int64

# %%
covid_df.dtypes
# Out:
# SNo                  int64
# ObservationDate     object
# Province/State      object
# Country/Region      object
# Last Update         object
# Confirmed          float64
# Deaths             float64
# Recovered          float64
# dtype: object

# %%
covid_df.isnull().sum()
# Out:
# SNo                    0
# ObservationDate        0
# Province/State     31153
# Country/Region         0
# Last Update            0
# Confirmed              0
# Deaths                 0
# Recovered              0
# dtype: int64

# %% [markdown]
# #### relating the variables with scatterplots

# %%
sns.relplot(x="Confirmed", y="Deaths", data=covid_df) 
# this show the relationship between age and gender columns

# %%
sns.relplot(x="Confirmed", y="Deaths", hue='Country/Region', data=covid_df) 
# this show the relationship between age and gender columns

# %%
sns.heatmap(covid_df.isnull())
# displays the columns with null values

# %% [markdown]
# ### Calculations

# %%
# 1. cal. the number of confirmed, deaths and recovered in each region/country
covid_df.groupby('Country/Region').sum()
# Out:
#                                     SNo  Confirmed    Deaths  Recovered
# Country/Region
#  Azerbaijan                        2664        1.0       0.0        0.0
# ('St. Martin',)                    4675        2.0       0.0        0.0
# Afghanistan                     7279094  3169169.0   93404.0  1685227.0
# Albania                         7235841   428662.0   12698.0   240272.0
# Algeria                         7276039  2394260.0  122159.0  1600110.0
# ...                                 ...        ...       ...        ...
# Western Sahara                  7050661     1231.0      96.0      912.0
# Yemen                           6987078   127748.0   35043.0    55925.0
# Zambia                          7216150   418038.0   10273.0   327756.0
# Zimbabwe                        7202656   213135.0    4820.0   100409.0
# occupied Palestinian territory    38803       25.0       0.0        0.0
#
# [223 rows x 4 columns]

# %%
covid_df.groupby('Country/Region')['Confirmed'].sum().sort_values(ascending=False)
# displays the numbers of confrimed cases
# Out:
# Country/Region
# US                       396234081.0
# Brazil                   194933354.0
# India                    122656809.0
# Russia                    75257596.0
# Spain                     38921479.0
#                             ...
# Republic of the Congo            1.0
# North Ireland                    1.0
# East Timor                       1.0
# Channel Islands                  1.0
#  Azerbaijan                      1.0
# Name: Confirmed, Length: 223, dtype: float64

# %%
covid_df.groupby('Country/Region')['Deaths', 'Recovered'].sum()
# displays the numbers of confrimed, deaths and recovered cases
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-fb3eb08672b6> in <module>
# ----> 1 covid_df.groupby('Country/Region')['Deaths', 'Recovered'].sum()
#       2 # displays the numbers of confrimed, deaths and recovered cases
#
# AttributeError: 'list' object has no attribute 'groupby'

# %%
# Remove all records where records of 10 confirmed cases exist
covid_df = [covid_df['Confirmed']>10]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-1d43bd71e633> in <module>
#       1 # Remove all records where records of 10 confirmed cases exist
# ----> 2 covid_df = [covid_df['Confirmed']>10]
#
# TypeError: list indices must be integers or slices, not str

# %% [markdown]
# ## Conclusion
